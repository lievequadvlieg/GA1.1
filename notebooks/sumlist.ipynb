# %%
def add(a, b):
    return a + b

# %%
def sum_list(values):
    result = 0
    for i in range(len(values)):
        result = add(result, values[i])
    print(result)

# %%
o = [1,2,3]
sum_list(o)
# Out:
# 6
